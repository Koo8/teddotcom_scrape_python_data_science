# %% [markdown]
# ## Scrape Talks Data from ted.com

# %% [markdown]
# #### As of Today (May,01 2022), There are 5033 talks on ted.com posted on total 154 pages. In order to scrape all talks of the site, I need to go to each page to do the scraping.

# %% [markdown]
# ***Data to be collected from each talk:***<br>
# title, speaker, posted_on date, talk_link

# %%
# !pip install requests_html

# %%
from requests_html import AsyncHTMLSession
import json
import asyncio

# %% [markdown]
# #### Make a list to store all talks later

# %%
all_talks = []

# %% [markdown]
# #### Method for start a session

# %%
def get_all_talks_pages_urls():
    links=[]
    for i in range(1,155):
        link = f'https://www.ted.com/talks?page={i}'
        links.append(link)
    return links

# %% [markdown]
# #### Scrape one page is one task, for each page, collect all '.col' info about each talk and store them into a dictionary.
# *In order to run all tasks in one event_loop, asession is used for passing around the AsyncHTMLSession *

# %%
async def get_all_talks_from_one_page(url, asession):    
    a_re = await asession.get(url)    
    row = a_re.html.find('div.row.row-sm-4up.row-lg-6up.row-skinny', first=True)
    all_cols = row.find('div.col')

    for col in all_cols:
        speaker = col.find('h4', first=True).text
        a_tag = col.find('div.media__message a.ga-link', first=True)
        title = a_tag.text
        talk_link = a_tag.attrs['href']
        post_date = col.find('span.meta__val', first=True).text
                 
        talk_dict = {
            'title':title,
            'speaker': speaker,
            'posted_on': post_date,
            'talk_link': talk_link
        }
        all_talks.append(talk_dict)
    return all_talks

# %% [markdown]
# #### The top-level function to call a new session and asyncio.gather() all tasks

# %%
async def scrape_all_talks():
    asession = AsyncHTMLSession()
    links = get_all_talks_pages_urls()
    tasks = (get_all_talks_from_one_page(link, asession) for link in links[:2]) # generator
    return await asyncio.gather(*tasks)

# %% [markdown]
# #### Run the top-level coroutine using asyncio.run()
# **Note:**
# On Jupyter Notebook, since there is an eventloop running already, use the following will work. However, for python code, this part should go like this: asyncio.run(scrape_all_talks())

# %%
await scrape_all_talks()
# Out:
# [[{'title': '"I Hope" / "DAWN"',
#    'speaker': 'Resistance Revival Chorus',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/resistance_revival_chorus_i_hope_dawn'},
#   {'title': '"A seat at the table" isn\'t the solution for gender equity',
#    'speaker': 'Lilly Singh',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/lilly_singh_a_seat_at_the_table_isn_t_the_solution_for_gender_equity'},
#   {'title': 'Why US laws must expand beyond the nuclear family',
#    'speaker': 'Diana Adams',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/diana_adams_why_us_laws_must_expand_beyond_the_nuclear_family'},
#   {'title': 'The ingredient in almost everything you eat',
#    'speaker': 'Francesca Bot',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/francesca_bot_the_ingredient_in_almost_everything_you_eat'},
#   {'title': 'What seaweed and cow burps have to do with climate change',
#    'speaker': 'Ermias Kebreab',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/ermias_kebreab_what_seaweed_and_cow_burps_have_to_do_with_climate_change'},
#   {'title': 'The war in Ukraine could change everything',
#    'speaker': 'Yuval Noah Harari',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/yuval_noah_harari_the_war_in_ukraine_could_change_everything'},
#   {'title': "3 ways your company's data can jump-start climate action",
#    'speaker': 'Massimo Russo',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/massimo_russo_3_ways_your_company_s_data_can_jump_start_climate_action'},
#   {'title': 'The dark history of the suburbs',
#    'speaker': 'Kevin Ehrman-Solberg and Kirsten Delegard',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/kevin_ehrman_solberg_and_kirsten_delegard_the_dark_history_of_the_suburbs'},
#   {'title': 'My secret to creating real magic',
#    'speaker': 'Christina Tosi',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/christina_tosi_my_secret_to_creating_real_magic'},
#   {'title': 'The carbonless fuel that could change how we ship goods',
#    'speaker': 'Maria Gallucci',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/maria_gallucci_the_carbonless_fuel_that_could_change_how_we_ship_goods'},
#   {'title': '"This Town" / "Too Far Gone"',
#    'speaker': 'Hannah Fisher and Sorren Maclean',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/hannah_fisher_and_sorren_maclean_this_town_too_far_gone'},
#   {'title': 'Can you survive the creation of the universe by solving this riddle?',
#    'speaker': 'James Tanton',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/james_tanton_can_you_survive_the_creation_of_the_universe_by_solving_this_riddle'},
#   {'title': 'The counterintuitive psychology of insurance',
#    'speaker': 'Orit Tykocinski',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/orit_tykocinski_the_counterintuitive_psychology_of_insurance'},
#   {'title': 'Are ad agencies, PR firms and lobbyists destroying the climate?',
#    'speaker': 'Solitaire Townsend',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/solitaire_townsend_are_ad_agencies_pr_firms_and_lobbyists_destroying_the_climate'},
#   {'title': 'Building the impossible: Golden Gate Bridge',
#    'speaker': 'Alex Gendler',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/alex_gendler_building_the_impossible_golden_gate_bridge'},
#   {'title': 'The "greenhouse-in-a-box" empowering farmers in India',
#    'speaker': 'Sathya Raghu Mokkapati',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/sathya_raghu_mokkapati_the_greenhouse_in_a_box_empowering_farmers_in_india'},
#   {'title': 'Climate action needs new frontline leadership',
#    'speaker': 'Ozawa Bineshi Albert',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/ozawa_bineshi_albert_climate_action_needs_new_frontline_leadership'},
#   {'title': 'The dark history of the overthrow of Hawaii',
#    'speaker': 'Sydney Iaukea',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/sydney_iaukea_the_dark_history_of_the_overthrow_of_hawaii'},
#   {'title': 'Why play is essential for business',
#    'speaker': 'Martin Reeves',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/martin_reeves_why_play_is_essential_for_business'},
#   {'title': 'Why is China appointing judges to combat climate change?',
#    'speaker': 'James K. Thornton',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/james_k_thornton_why_is_china_appointing_judges_to_combat_climate_change'},
#   {'title': "Cement's carbon problem — and 2 ways to fix it",
#    'speaker': 'Mahendra Singhi',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/mahendra_singhi_cement_s_carbon_problem_and_2_ways_to_fix_it'},
#   {'title': 'The tragedy of air pollution — and an urgent demand for clean air',
#    'speaker': 'Rosamund Adoo-Kissi-Debrah',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/rosamund_adoo_kissi_debrah_the_tragedy_of_air_pollution_and_an_urgent_demand_for_clean_air'},
#   {'title': 'The myth of Narcissus and Echo',
#    'speaker': 'Iseult Gillespie',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/iseult_gillespie_the_myth_of_narcissus_and_echo'},
#   {'title': 'You deserve the right to repair your stuff',
#    'speaker': 'Gay Gordon-Byrne',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/gay_gordon_byrne_you_deserve_the_right_to_repair_your_stuff'},
#   {'title': 'What nature can teach us about sustainable business',
#    'speaker': 'Erin Meezan',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/erin_meezan_what_nature_can_teach_us_about_sustainable_business'},
#   {'title': 'The origins of blackface and Black stereotypes',
#    'speaker': 'Dwan Reece',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/dwan_reece_the_origins_of_blackface_and_black_stereotypes'},
#   {'title': "A sex therapist's secret to rediscovering your spark",
#    'speaker': 'Ian Kerner',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/ian_kerner_a_sex_therapist_s_secret_to_rediscovering_your_spark'},
#   {'title': "How do jetpacks work? And why don't we all have them?",
#    'speaker': 'Richard Browning',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/richard_browning_how_do_jetpacks_work_and_why_don_t_we_all_have_them'},
#   {'title': '4 kinds of regret — and what they teach you about yourself',
#    'speaker': 'Daniel H. Pink',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/daniel_h_pink_4_kinds_of_regret_and_what_they_teach_you_about_yourself'},
#   {'title': 'How to fix the "bugs" in the net-zero code',
#    'speaker': 'Lucas Joppa',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/lucas_joppa_how_to_fix_the_bugs_in_the_net_zero_code'},
#   {'title': '"Big Yellow Taxi" / "Song for Sunshine"',
#    'speaker': 'Belle and Sebastian',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/belle_and_sebastian_big_yellow_taxi_song_for_sunshine'},
#   {'title': 'How film captures the space between hope and despair',
#    'speaker': 'Mounia Akl',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/mounia_akl_how_film_captures_the_space_between_hope_and_despair'},
#   {'title': 'What is "normal" and what is "different"?',
#    'speaker': 'Yana Buhrer Tavanier',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/yana_buhrer_tavanier_what_is_normal_and_what_is_different'},
#   {'title': "The ocean's ingenious climate solutions",
#    'speaker': 'Susan Ruffo',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/susan_ruffo_the_ocean_s_ingenious_climate_solutions'},
#   {'title': "How we're reducing the climate impact of electronics",
#    'speaker': 'Tim Dunn',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/tim_dunn_how_we_re_reducing_the_climate_impact_of_electronics'},
#   {'title': 'A vibrant dance performance of funk classics',
#    'speaker': 'Let It Happen',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/let_it_happen_a_vibrant_dance_performance_of_funk_classics'},
#   {'title': 'Why the Sun could crash your internet',
#    'speaker': 'Fabio Pacucci',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/fabio_pacucci_why_the_sun_could_crash_your_internet'},
#   {'title': 'A vision for sustainability in aviation',
#    'speaker': 'Shai Weiss',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/shai_weiss_a_vision_for_sustainability_in_aviation'},
#   {'title': "How we're turning carbon waste into jet fuel (and everything else)",
#    'speaker': 'Jennifer Holmgren',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/jennifer_holmgren_how_we_re_turning_carbon_waste_into_jet_fuel_and_everything_else'},
#   {'title': 'The 100 tampons NASA (almost) sent to space — and other absurd songs',
#    'speaker': 'Marcia Belsky',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/marcia_belsky_the_100_tampons_nasa_almost_sent_to_space_and_other_absurd_songs'},
#   {'title': '"Everything I Need" / "Find Your Tribe" / "I Am Free"',
#    'speaker': 'Geminelle',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/geminelle_everything_i_need_find_your_tribe_i_am_free'},
#   {'title': "What it's like to be a war refugee",
#    'speaker': 'Zarlasht Halaimzai',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/zarlasht_halaimzai_what_it_s_like_to_be_a_war_refugee'},
#   {'title': 'How webtoons are changing movies and TV',
#    'speaker': 'Hyeonmi Kim',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/hyeonmi_kim_how_webtoons_are_changing_movies_and_tv'},
#   {'title': 'What my gender transition taught me about womanhood',
#    'speaker': 'Paula Stone Williams',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/paula_stone_williams_what_my_gender_transition_taught_me_about_womanhood'},
#   {'title': 'A riddle of ice and fire dragons',
#    'speaker': 'Henri Picciotto',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/henri_picciotto_a_riddle_of_ice_and_fire_dragons'},
#   {'title': 'Goats, blockchain and the future of money',
#    'speaker': 'Fariel Salahuddin',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/fariel_salahuddin_goats_blockchain_and_the_future_of_money'},
#   {'title': 'What does a voice of the future sound like?',
#    'speaker': 'Reeps One',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/reeps_one_what_does_a_voice_of_the_future_sound_like'},
#   {'title': 'Why all melodies should be free for musicians to use',
#    'speaker': 'Damien Riehl',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/damien_riehl_why_all_melodies_should_be_free_for_musicians_to_use'},
#   {'title': 'The Chinese legend of the butterfly lovers',
#    'speaker': 'Lijun Zhang',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/lijun_zhang_the_chinese_legend_of_the_butterfly_lovers'},
#   {'title': "The African swamp protecting Earth's environment",
#    'speaker': 'Vera Songwe',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/vera_songwe_the_african_swamp_protecting_earth_s_environment'},
#   {'title': 'The future will be shaped by optimists',
#    'speaker': 'Kevin Kelly',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/kevin_kelly_the_future_will_be_shaped_by_optimists'},
#   {'title': "How do you know you're not dreaming?",
#    'speaker': 'Daniel Gregory',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/daniel_gregory_how_do_you_know_you_re_not_dreaming'},
#   {'title': 'The hidden power of sad songs and rainy days',
#    'speaker': 'Susan Cain and Min Kym',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/susan_cain_and_min_kym_the_hidden_power_of_sad_songs_and_rainy_days'},
#   {'title': 'Powerful photos that honor the lives of overlooked women',
#    'speaker': 'Smita Sharma',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/smita_sharma_powerful_photos_that_honor_the_lives_of_overlooked_women'},
#   {'title': 'Why entrepreneurship flourishes in the countryside',
#    'speaker': 'Xiaowei R. Wang',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/xiaowei_r_wang_why_entrepreneurship_flourishes_in_the_countryside'},
#   {'title': "The deep sea's medicinal secrets",
#    'speaker': 'Sam Afoullouss',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/sam_afoullouss_the_deep_sea_s_medicinal_secrets'},
#   {'title': '4 signs of emotional abuse',
#    'speaker': 'Viann Nguyen-Feng',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/viann_nguyen_feng_4_signs_of_emotional_abuse'},
#   {'title': 'The power of purpose in business',
#    'speaker': 'Ashley M. Grice',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/ashley_m_grice_the_power_of_purpose_in_business'},
#   {'title': "Climate change isn't a distant threat — it's our reality",
#    'speaker': 'Selina Neirok Leem',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/selina_neirok_leem_climate_change_isn_t_a_distant_threat_it_s_our_reality'},
#   {'title': 'How pigeons took over the world',
#    'speaker': 'Elizabeth Carlen and Joanna Moles',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/elizabeth_carlen_and_joanna_moles_how_pigeons_took_over_the_world'},
#   {'title': '3 things men can do to promote gender equity',
#    'speaker': 'Jimmie Briggs',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/jimmie_briggs_3_things_men_can_do_to_promote_gender_equity'},
#   {'title': 'Self-assembling robots and the potential of artificial evolution',
#    'speaker': 'Emma Hart',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/emma_hart_self_assembling_robots_and_the_potential_of_artificial_evolution'},
#   {'title': 'What does it mean to be a refugee?',
#    'speaker': 'Benedetta Berti and Evelien Borgman',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/benedetta_berti_and_evelien_borgman_what_does_it_mean_to_be_a_refugee_mar_2018'},
#   {'title': 'War in Ukraine — and what it means for the world order',
#    'speaker': 'Ian Bremmer',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/ian_bremmer_war_in_ukraine_and_what_it_means_for_the_world_order'},
#   {'title': 'How to design mosquitoes out of cities',
#    'speaker': 'Cameron Webb',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/cameron_webb_how_to_design_mosquitoes_out_of_cities'},
#   {'title': 'An aerial perspective on renewable energy',
#    'speaker': 'Jamey Stillings',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/jamey_stillings_an_aerial_perspective_on_renewable_energy'},
#   {'title': 'The movement that inspired the Holocaust',
#    'speaker': 'Alexandra Minna Stern and Natalie Lira',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/alexandra_minna_stern_and_natalie_lira_the_movement_that_inspired_the_holocaust'},
#   {'title': 'The critical role of Black mothers — and how to support all moms',
#    'speaker': 'Anna Malaika Tubbs',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/anna_malaika_tubbs_the_critical_role_of_black_mothers_and_how_to_support_all_moms'},
#   {'title': 'The creativity and community behind fanfiction',
#    'speaker': 'Cecilia Aragon',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/cecilia_aragon_the_creativity_and_community_behind_fanfiction'},
#   {'title': '3 ways to find hope in hopeless times',
#    'speaker': 'Wajahat Ali',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/wajahat_ali_3_ways_to_find_hope_in_hopeless_times'},
#   {'title': 'The myth of the moon goddess',
#    'speaker': 'Cynthia Fay Davis',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/cynthia_fay_davis_the_myth_of_the_moon_goddess'},
#   {'title': 'How to share public money fairly',
#    'speaker': 'Maja Bosnic',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/maja_bosnic_how_to_share_public_money_fairly'},
#   {'title': 'The most powerful untapped resource in health care',
#    'speaker': 'Edith Elliott and Shahed Alam',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/edith_elliott_and_shahed_alam_the_most_powerful_untapped_resource_in_health_care'},
#   {'title': 'A bold plan for transforming access to the US social safety net',
#    'speaker': 'Amanda Renteria',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/amanda_renteria_a_bold_plan_for_transforming_access_to_the_us_social_safety_net'},
#   {'title': 'A transparent, easy way for smallholder farmers to save',
#    'speaker': 'Anushka Ratnayake',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/anushka_ratnayake_a_transparent_easy_way_for_smallholder_farmers_to_save'},
#   {'title': 'An election redesign to restore trust in US democracy',
#    'speaker': 'Tiana Epps-Johnson',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/tiana_epps_johnson_an_election_redesign_to_restore_trust_in_us_democracy'},
#   {'title': 'Mental health care that disrupts cycles of violence',
#    'speaker': 'Celina de Sola',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/celina_de_sola_mental_health_care_that_disrupts_cycles_of_violence'},
#   {'title': 'How ancient Arctic carbon threatens everyone on the planet',
#    'speaker': 'Sue Natali',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/sue_natali_how_ancient_arctic_carbon_threatens_everyone_on_the_planet'},
#   {'title': 'Why Indigenous forest guardianship is crucial to climate action',
#    'speaker': 'Nonette Royo',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/nonette_royo_why_indigenous_forest_guardianship_is_crucial_to_climate_action'},
#   {'title': 'A safe pathway to resettlement for migrants and refugees',
#    'speaker': 'Becca Heller',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/becca_heller_a_safe_pathway_to_resettlement_for_migrants_and_refugees'},
#   {'title': 'How to heal a divided world',
#    'speaker': 'Michèle Lamont',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/michele_lamont_how_to_heal_a_divided_world'},
#   {'title': 'The restorative power of medical tattoos',
#    'speaker': 'Becky Barker',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/becky_barker_the_restorative_power_of_medical_tattoos'},
#   {'title': 'The myth of the original star-crossed lovers',
#    'speaker': 'Shannon Zhao',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/shannon_zhao_the_myth_of_the_original_star_crossed_lovers'},
#   {'title': 'The breakthrough science of mRNA medicine',
#    'speaker': 'Melissa J. Moore',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/melissa_j_moore_the_breakthrough_science_of_mrna_medicine'},
#   {'title': 'Can you solve the feeding frenzy riddle?',
#    'speaker': 'Henri Picciotto',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/henri_picciotto_can_you_solve_the_feeding_frenzy_riddle'},
#   {'title': 'The funding gap in start-up investing',
#    'speaker': 'Temie Giwa-Tubosun',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/temie_giwa_tubosun_the_funding_gap_in_start_up_investing'},
#   {'title': 'How the James Webb Space Telescope will unfold the universe',
#    'speaker': 'John C. Mather',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/john_c_mather_how_the_james_webb_space_telescope_will_unfold_the_universe'},
#   {'title': 'We can make COVID-19 the last pandemic',
#    'speaker': 'Bill Gates',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/bill_gates_we_can_make_covid_19_the_last_pandemic'},
#   {'title': 'Why people and AI make good business partners',
#    'speaker': 'Shervin Khodabandeh',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/shervin_khodabandeh_why_people_and_ai_make_good_business_partners'},
#   {'title': 'The dark history of zombies',
#    'speaker': 'Christopher M. Moreman',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/christopher_m_moreman_the_dark_history_of_zombies'},
#   {'title': 'A new economic model for protecting tropical forests',
#    'speaker': 'Nat Keohane',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/nat_keohane_a_new_economic_model_for_protecting_tropical_forests'},
#   {'title': "An Olympic champion's mindset for overcoming fear",
#    'speaker': 'Allyson Felix',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/allyson_felix_an_olympic_champion_s_mindset_for_overcoming_fear'},
#   {'title': 'Why are cockroaches so hard to kill?',
#    'speaker': 'Ameya Gondhalekar',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/ameya_gondhalekar_why_are_cockroaches_so_hard_to_kill'},
#   {'title': 'A future worth getting excited about',
#    'speaker': 'Elon Musk',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/elon_musk_a_future_worth_getting_excited_about'},
#   {'title': 'Elon Musk talks Twitter, Tesla and how his brain works — live at TED2022',
#    'speaker': 'Elon Musk',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/elon_musk_elon_musk_talks_twitter_tesla_and_how_his_brain_works_live_at_ted2022'},
#   {'title': 'The myth of Hades and Persephone',
#    'speaker': 'Iseult Gillespie',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/iseult_gillespie_the_myth_of_hades_and_persephone'},
#   {'title': "Ukraine's fight to keep educating its children",
#    'speaker': 'Zoya Lytvyn',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/zoya_lytvyn_ukraine_s_fight_to_keep_educating_its_children'},
#   {'title': 'Nuclear threat and the war in Ukraine',
#    'speaker': 'Emma Belcher',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/emma_belcher_nuclear_threat_and_the_war_in_ukraine'},
#   {'title': 'The likability dilemma for women leaders',
#    'speaker': 'Robin Hauser',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/robin_hauser_the_likability_dilemma_for_women_leaders_apr_2022'},
#   {'title': 'Ethical dilemma: Who should you believe?',
#    'speaker': 'Alex Worsnip',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/alex_worsnip_ethical_dilemma_who_should_you_believe'},
#   {'title': 'Stand with Ukraine in the fight against evil',
#    'speaker': 'Garry Kasparov',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/garry_kasparov_stand_with_ukraine_in_the_fight_against_evil'},
#   {'title': 'We could kick-start life on another planet. Should we?',
#    'speaker': 'Betül Kaçar',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/betul_kacar_we_could_kick_start_life_on_another_planet_should_we'},
#   {'title': "If you're scared of snakes, watch this",
#    'speaker': 'Andrew Whitworth',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/andrew_whitworth_if_you_re_scared_of_snakes_watch_this'},
#   {'title': 'The rhythm and rhyme of memory, solitude and community',
#    'speaker': 'Rosanne Cash',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/rosanne_cash_the_rhythm_and_rhyme_of_memory_solitude_and_community'},
#   {'title': '5 promising factors propelling climate action',
#    'speaker': 'Gabriel Kra',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/gabriel_kra_5_promising_factors_propelling_climate_action'},
#   {'title': 'NFTs, the metaverse and the future of digital art',
#    'speaker': 'Elizabeth Strickler',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/elizabeth_strickler_nfts_the_metaverse_and_the_future_of_digital_art'},
#   {'title': 'History vs. Tamerlane the Conqueror',
#    'speaker': 'Stephanie Honchell Smith',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/stephanie_honchell_smith_history_vs_tamerlane_the_conqueror'},
#   {'title': 'Live drawings of the human experience',
#    'speaker': 'Jarrett J. Krosoczka',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/jarrett_j_krosoczka_live_drawings_of_the_human_experience'},
#   {'title': 'The creativity, innovation and ingenuity languishing in US prisons',
#    'speaker': 'Brittany K. Barnett',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/brittany_k_barnett_the_creativity_innovation_and_ingenuity_languishing_in_us_prisons'},
#   {'title': 'The architectural mastermind behind modern Singapore',
#    'speaker': 'Liu Thai Ker',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/liu_thai_ker_the_architectural_mastermind_behind_modern_singapore'},
#   {'title': "The myth of Loki's monstrous children",
#    'speaker': 'Iseult Gillespie',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/iseult_gillespie_the_myth_of_loki_s_monstrous_children'},
#   {'title': 'What makes a job "good" — and the case for investing in people',
#    'speaker': 'Warren Valdmanis',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/warren_valdmanis_what_makes_a_job_good_and_the_case_for_investing_in_people'},
#   {'title': "Language shouldn't be a barrier to climate action",
#    'speaker': 'Sophia Kianni',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/sophia_kianni_language_shouldn_t_be_a_barrier_to_climate_action'},
#   {'title': 'Human-centered justice',
#    'speaker': 'American Family Insurance',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/american_family_insurance_human_centered_justice'},
#   {'title': 'Why is the Mona Lisa so famous?',
#    'speaker': 'Noah Charney',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/noah_charney_why_is_the_mona_lisa_so_famous'},
#   {'title': 'How moms shape the world',
#    'speaker': 'Anna Malaika Tubbs',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/anna_malaika_tubbs_how_moms_shape_the_world'},
#   {'title': 'Why a free and fair internet is more vital than ever',
#    'speaker': 'Priscilla Chomba-Kinywa',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/priscilla_chomba_kinywa_why_a_free_and_fair_internet_is_more_vital_than_ever'},
#   {'title': "It's time to write a new climate story",
#    'speaker': 'Countdown',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/countdown_it_s_time_to_write_a_new_climate_story'},
#   {'title': 'Blood, concrete, and dynamite: Building the Hoover Dam',
#    'speaker': 'Alex Gendler',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/alex_gendler_blood_concrete_and_dynamite_building_the_hoover_dam'},
#   {'title': '4 ways the COVID-19 pandemic changed the way we sleep',
#    'speaker': 'Matt Walker',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/matt_walker_4_ways_the_covid_19_pandemic_changed_the_way_we_sleep'},
#   {'title': 'You can only save one— who do you choose?',
#    'speaker': 'Doug MacKay',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/doug_mackay_you_can_only_save_one_who_do_you_choose'},
#   {'title': 'How to escape the cynicism trap',
#    'speaker': 'Jamil Zaki',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/jamil_zaki_how_to_escape_the_cynicism_trap'},
#   {'title': 'Use your voice, vote and wallet for climate action',
#    'speaker': 'Halla Tómasdóttir',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/halla_tomasdottir_use_your_voice_vote_and_wallet_for_climate_action'},
#   {'title': 'A king cobra bite — and a scientific discovery',
#    'speaker': 'Gowri Shankar',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/gowri_shankar_a_king_cobra_bite_and_a_scientific_discovery'},
#   {'title': 'How we could better predict and stop floods',
#    'speaker': 'Virginia Smith',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/virginia_smith_how_we_could_better_predict_and_stop_floods'},
#   {'title': 'Dreams and details for a decarbonized future',
#    'speaker': 'Jim Hagemann Snabe',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/jim_hagemann_snabe_dreams_and_details_for_a_decarbonized_future'},
#   {'title': 'The dark history of Mount Rushmore',
#    'speaker': 'Ned Blackhawk and Jeffrey D. Means',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/ned_blackhawk_and_jeffrey_d_means_the_dark_history_of_mount_rushmore'},
#   {'title': 'Siri, Alexa, Google ... what comes next?',
#    'speaker': 'Karen Lellouche Tordjman',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/karen_lellouche_tordjman_siri_alexa_google_what_comes_next'},
#   {'title': 'A new way to help young people with their mental health',
#    'speaker': 'Tom Osborn',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/tom_osborn_a_new_way_to_help_young_people_with_their_mental_health'},
#   {'title': 'How to deal with your insomnia — and finally get to sleep',
#    'speaker': 'Matt Walker',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/matt_walker_how_to_deal_with_your_insomnia_and_finally_get_to_sleep'},
#   {'title': 'Would you raise the bird that murdered your children?',
#    'speaker': 'Steve Rothstein',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/steve_rothstein_would_you_raise_the_bird_that_murdered_your_children'},
#   {'title': 'A vision of sustainable housing for all of humanity',
#    'speaker': 'Vishaan Chakrabarti',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/vishaan_chakrabarti_a_vision_of_sustainable_housing_for_all_of_humanity'},
#   {'title': '"Your Song" / "Real Life"',
#    'speaker': 'Joan As Police Woman',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/joan_as_police_woman_your_song_real_life'},
#   {'title': '3 ways to prepare society for the next pandemic',
#    'speaker': 'Jennifer B. Nuzzo',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/jennifer_b_nuzzo_3_ways_to_prepare_society_for_the_next_pandemic'},
#   {'title': 'The need for family reunification — to make families whole again',
#    'speaker': 'Elizabeth Zion',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/elizabeth_zion_the_need_for_family_reunification_to_make_families_whole_again'},
#   {'title': 'Education is a fundamental right for every child',
#    'speaker': 'Makhtoum Abdalla',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/makhtoum_abdalla_education_is_a_fundamental_right_for_every_child'},
#   {'title': 'The life-changing power of assistive technologies',
#    'speaker': 'Jane Velkovski',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/jane_velkovski_the_life_changing_power_of_assistive_technologies'},
#   {'title': 'How to protect your mental well-being online — from a Gen-Zer',
#    'speaker': 'Peachy Liv',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/peachy_liv_how_to_protect_your_mental_well_being_online_from_a_gen_zer'},
#   {'title': 'A next-generation solution to the climate crisis',
#    'speaker': 'Nkosilathi Nyathi',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/nkosilathi_nyathi_a_next_generation_solution_to_the_climate_crisis'},
#   {'title': '"Astral Plane"',
#    'speaker': 'Valerie June',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/valerie_june_astral_plane'},
#   {'title': '5 keys to shifting to a well-being economy — and the cost of inaction',
#    'speaker': 'Sandrine Dixson-Declève',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/sandrine_dixson_decleve_5_keys_to_shifting_to_a_well_being_economy_and_the_cost_of_inaction'},
#   {'title': '3 ways to lower the barriers to higher education',
#    'speaker': 'Adrian K. Haugabrook',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/adrian_k_haugabrook_3_ways_to_lower_the_barriers_to_higher_education'},
#   {'title': 'How one of the most profitable companies in history rose to power',
#    'speaker': 'Adam Clulow',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/adam_clulow_how_one_of_the_most_profitable_companies_in_history_rose_to_power'},
#   {'title': 'How going to Mars improves life on Earth',
#    'speaker': 'Eric Hinterman',
#    'posted_on': 'Dec 2021',
#    'talk_link': '/talks/eric_hinterman_how_going_to_mars_improves_life_on_earth'},
#   {'title': '"Dive In"',
#    'speaker': 'Dave Matthews',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/dave_matthews_dive_in'},
#   {'title': 'Got millet? How marketing could improve the lives of African farmers',
#    'speaker': 'Zoë Karl-Waithaka',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/zoe_karl_waithaka_got_millet_how_marketing_could_improve_the_lives_of_african_farmers'},
#   {'title': 'The myth of Gawain and the Green Knight',
#    'speaker': 'Dan Kwartler',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/dan_kwartler_the_myth_of_gawain_and_the_green_knight'},
#   {'title': 'How wind energy could power Earth ... 18 times over',
#    'speaker': 'Dan Jørgensen',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/dan_jorgensen_how_wind_energy_could_power_earth_18_times_over'},
#   {'title': 'The incredible cancer-detecting potential of photoacoustic imaging',
#    'speaker': 'Lei Li',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/lei_li_the_incredible_cancer_detecting_potential_of_photoacoustic_imaging'},
#   {'title': 'How to fix two of the most broken systems in the US',
#    'speaker': 'Nick Turner and Whitney Pennington Rodgers',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/nick_turner_and_whitney_pennington_rodgers_how_to_fix_two_of_the_most_broken_systems_in_the_us'},
#   {'title': 'Can you outsmart the fallacy that divided a nation?',
#    'speaker': 'Elizabeth Cox',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/elizabeth_cox_can_you_outsmart_the_fallacy_that_divided_a_nation'},
#   {'title': 'Sex education should start with consent',
#    'speaker': 'Kaz',
#    'posted_on': 'Feb 2022',
#    'talk_link': '/talks/kaz_sex_education_should_start_with_consent'},
#   {'title': 'Smart solutions to decarbonize buildings',
#    'speaker': 'Katie McGinty',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/katie_mcginty_smart_solutions_to_decarbonize_buildings'},
#   {'title': "Sustainable cooling that doesn't warm the planet",
#    'speaker': 'Rachel Kyte',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/rachel_kyte_sustainable_cooling_that_doesn_t_warm_the_planet'},
#   {'title': 'The mind-bending art of deep time',
#    'speaker': 'Katie Paterson',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/katie_paterson_the_mind_bending_art_of_deep_time'},
#   {'title': 'The myth of Anansi, the trickster spider',
#    'speaker': 'Emily Zobel Marshall',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/emily_zobel_marshall_the_myth_of_anansi_the_trickster_spider'},
#   {'title': 'A different understanding of American patriotism',
#    'speaker': 'Deval Patrick',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/deval_patrick_a_different_understanding_of_american_patriotism'},
#   {'title': '4 ways to redefine power at work to include women of color',
#    'speaker': 'Rha Goddess and Deepa Purushothaman',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/rha_goddess_and_deepa_purushothaman_4_ways_to_redefine_power_at_work_to_include_women_of_color'},
#   {'title': 'How to boost nature-based solutions to climate change',
#    'speaker': 'Zac Goldsmith',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/zac_goldsmith_how_to_boost_nature_based_solutions_to_climate_change'},
#   {'title': 'Which animal has the best eyesight?',
#    'speaker': 'Thomas W. Cronin',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/thomas_w_cronin_which_animal_has_the_best_eyesight'},
#   {'title': 'The new reality of fashion is digital',
#    'speaker': 'Gala Marija Vrbanic',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/gala_marija_vrbanic_the_new_reality_of_fashion_is_digital'},
#   {'title': "Could we treat Alzheimer's with light and sound?",
#    'speaker': 'Li-Huei Tsai',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/li_huei_tsai_could_we_treat_alzheimer_s_with_light_and_sound'},
#   {'title': 'What if women built the world they want to see?',
#    'speaker': 'Emily Pilloton-Lam',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/emily_pilloton_lam_what_if_women_built_the_world_they_want_to_see'},
#   {'title': 'How to fix broken supply chains',
#    'speaker': 'Dustin Burke',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/dustin_burke_how_to_fix_broken_supply_chains'},
#   {'title': 'Can you solve the birthday cake riddle?',
#    'speaker': 'Marie Brodsky',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/marie_brodsky_can_you_solve_the_birthday_cake_riddle'},
#   {'title': 'What you need to know about carbon removal',
#    'speaker': 'Gabrielle Walker',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/gabrielle_walker_what_you_need_to_know_about_carbon_removal'},
#   {'title': 'How radical hospitality can change the lives of the formerly incarcerated',
#    'speaker': 'Reuben Jonathan Miller',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/reuben_jonathan_miller_how_radical_hospitality_can_change_the_lives_of_the_formerly_incarcerated'},
#   {'title': "The tragic myth of the Sun God's son",
#    'speaker': 'Iseult Gillespie',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/iseult_gillespie_the_tragic_myth_of_the_sun_god_s_son'},
#   {'title': 'The unexpected, underwater plant fighting climate change',
#    'speaker': 'Carlos M. Duarte',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/carlos_m_duarte_the_unexpected_underwater_plant_fighting_climate_change'},
#   {'title': 'How to break down barriers and not accept limits',
#    'speaker': 'Candace Parker',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/candace_parker_how_to_break_down_barriers_and_not_accept_limits'},
#   {'title': '"A Ride With Polly Jean" / "Ali Farka Touche"',
#    'speaker': 'Jenny Scheinman with Nels Cline and Todd Sickafoose',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/jenny_scheinman_with_nels_cline_and_todd_sickafoose_a_ride_with_polly_jean_ali_farka_touche'},
#   {'title': 'Why do cats have vertical pupils?',
#    'speaker': 'Emma Bryce',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/emma_bryce_why_do_cats_have_vertical_pupils'},
#   {'title': 'Why great leaders take humor seriously',
#    'speaker': 'Jennifer Aaker and Naomi Bagdonas',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/jennifer_aaker_and_naomi_bagdonas_why_great_leaders_take_humor_seriously'},
#   {'title': 'One company at a time',
#    'speaker': 'American Family Insurance',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/american_family_insurance_one_company_at_a_time'},
#   {'title': 'How visual storytelling creates better health care',
#    'speaker': 'Sam Hester',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/sam_hester_how_visual_storytelling_creates_better_health_care'},
#   {'title': 'Why is it so hard to escape poverty?',
#    'speaker': 'Ann-Helén Bay',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/ann_helen_bay_why_is_it_so_hard_to_escape_poverty'},
#   {'title': '"You and I" / "Attention"',
#    'speaker': 'Charlie Puth',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/charlie_puth_you_and_i_attention'},
#   {'title': 'How to realistically decarbonize the oil and gas industry',
#    'speaker': 'Bjørn Otto Sverdrup',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/bjorn_otto_sverdrup_how_to_realistically_decarbonize_the_oil_and_gas_industry'},
#   {'title': 'I\'m tired of people telling me to "grind"',
#    'speaker': 'Pardis Parker',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/pardis_parker_i_m_tired_of_people_telling_me_to_grind'},
#   {'title': 'How biochar removes CO2 from the air — and helps farmers thrive',
#    'speaker': 'Axel Reinaud',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/axel_reinaud_how_biochar_removes_co2_from_the_air_and_helps_farmers_thrive'},
#   {'title': 'The most powerful untapped resource in health care',
#    'speaker': 'Edith Elliott and Shahed Alam',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/edith_elliott_and_shahed_alam_the_most_powerful_untapped_resource_in_health_care'},
#   {'title': 'A bold plan for transforming access to the US social safety net',
#    'speaker': 'Amanda Renteria',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/amanda_renteria_a_bold_plan_for_transforming_access_to_the_us_social_safety_net'},
#   {'title': 'A transparent, easy way for smallholder farmers to save',
#    'speaker': 'Anushka Ratnayake',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/anushka_ratnayake_a_transparent_easy_way_for_smallholder_farmers_to_save'},
#   {'title': 'An election redesign to restore trust in US democracy',
#    'speaker': 'Tiana Epps-Johnson',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/tiana_epps_johnson_an_election_redesign_to_restore_trust_in_us_democracy'},
#   {'title': 'Mental health care that disrupts cycles of violence',
#    'speaker': 'Celina de Sola',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/celina_de_sola_mental_health_care_that_disrupts_cycles_of_violence'},
#   {'title': 'How ancient Arctic carbon threatens everyone on the planet',
#    'speaker': 'Sue Natali',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/sue_natali_how_ancient_arctic_carbon_threatens_everyone_on_the_planet'},
#   {'title': 'Why Indigenous forest guardianship is crucial to climate action',
#    'speaker': 'Nonette Royo',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/nonette_royo_why_indigenous_forest_guardianship_is_crucial_to_climate_action'},
#   {'title': 'A safe pathway to resettlement for migrants and refugees',
#    'speaker': 'Becca Heller',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/becca_heller_a_safe_pathway_to_resettlement_for_migrants_and_refugees'},
#   {'title': 'How to heal a divided world',
#    'speaker': 'Michèle Lamont',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/michele_lamont_how_to_heal_a_divided_world'},
#   {'title': 'The restorative power of medical tattoos',
#    'speaker': 'Becky Barker',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/becky_barker_the_restorative_power_of_medical_tattoos'},
#   {'title': 'The myth of the original star-crossed lovers',
#    'speaker': 'Shannon Zhao',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/shannon_zhao_the_myth_of_the_original_star_crossed_lovers'},
#   {'title': 'The breakthrough science of mRNA medicine',
#    'speaker': 'Melissa J. Moore',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/melissa_j_moore_the_breakthrough_science_of_mrna_medicine'},
#   {'title': 'Can you solve the feeding frenzy riddle?',
#    'speaker': 'Henri Picciotto',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/henri_picciotto_can_you_solve_the_feeding_frenzy_riddle'},
#   {'title': 'The funding gap in start-up investing',
#    'speaker': 'Temie Giwa-Tubosun',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/temie_giwa_tubosun_the_funding_gap_in_start_up_investing'},
#   {'title': 'How the James Webb Space Telescope will unfold the universe',
#    'speaker': 'John C. Mather',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/john_c_mather_how_the_james_webb_space_telescope_will_unfold_the_universe'},
#   {'title': 'We can make COVID-19 the last pandemic',
#    'speaker': 'Bill Gates',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/bill_gates_we_can_make_covid_19_the_last_pandemic'},
#   {'title': 'Why people and AI make good business partners',
#    'speaker': 'Shervin Khodabandeh',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/shervin_khodabandeh_why_people_and_ai_make_good_business_partners'},
#   {'title': 'The dark history of zombies',
#    'speaker': 'Christopher M. Moreman',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/christopher_m_moreman_the_dark_history_of_zombies'},
#   {'title': 'A new economic model for protecting tropical forests',
#    'speaker': 'Nat Keohane',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/nat_keohane_a_new_economic_model_for_protecting_tropical_forests'},
#   {'title': "An Olympic champion's mindset for overcoming fear",
#    'speaker': 'Allyson Felix',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/allyson_felix_an_olympic_champion_s_mindset_for_overcoming_fear'},
#   {'title': 'Why are cockroaches so hard to kill?',
#    'speaker': 'Ameya Gondhalekar',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/ameya_gondhalekar_why_are_cockroaches_so_hard_to_kill'},
#   {'title': 'A future worth getting excited about',
#    'speaker': 'Elon Musk',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/elon_musk_a_future_worth_getting_excited_about'},
#   {'title': 'Elon Musk talks Twitter, Tesla and how his brain works — live at TED2022',
#    'speaker': 'Elon Musk',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/elon_musk_elon_musk_talks_twitter_tesla_and_how_his_brain_works_live_at_ted2022'},
#   {'title': 'The myth of Hades and Persephone',
#    'speaker': 'Iseult Gillespie',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/iseult_gillespie_the_myth_of_hades_and_persephone'},
#   {'title': "Ukraine's fight to keep educating its children",
#    'speaker': 'Zoya Lytvyn',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/zoya_lytvyn_ukraine_s_fight_to_keep_educating_its_children'},
#   {'title': 'Nuclear threat and the war in Ukraine',
#    'speaker': 'Emma Belcher',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/emma_belcher_nuclear_threat_and_the_war_in_ukraine'},
#   {'title': 'The likability dilemma for women leaders',
#    'speaker': 'Robin Hauser',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/robin_hauser_the_likability_dilemma_for_women_leaders_apr_2022'},
#   {'title': 'Ethical dilemma: Who should you believe?',
#    'speaker': 'Alex Worsnip',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/alex_worsnip_ethical_dilemma_who_should_you_believe'},
#   {'title': 'Stand with Ukraine in the fight against evil',
#    'speaker': 'Garry Kasparov',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/garry_kasparov_stand_with_ukraine_in_the_fight_against_evil'},
#   {'title': 'We could kick-start life on another planet. Should we?',
#    'speaker': 'Betül Kaçar',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/betul_kacar_we_could_kick_start_life_on_another_planet_should_we'},
#   {'title': "If you're scared of snakes, watch this",
#    'speaker': 'Andrew Whitworth',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/andrew_whitworth_if_you_re_scared_of_snakes_watch_this'},
#   {'title': 'The rhythm and rhyme of memory, solitude and community',
#    'speaker': 'Rosanne Cash',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/rosanne_cash_the_rhythm_and_rhyme_of_memory_solitude_and_community'},
#   {'title': '5 promising factors propelling climate action',
#    'speaker': 'Gabriel Kra',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/gabriel_kra_5_promising_factors_propelling_climate_action'},
#   {'title': 'NFTs, the metaverse and the future of digital art',
#    'speaker': 'Elizabeth Strickler',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/elizabeth_strickler_nfts_the_metaverse_and_the_future_of_digital_art'},
#   {'title': 'History vs. Tamerlane the Conqueror',
#    'speaker': 'Stephanie Honchell Smith',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/stephanie_honchell_smith_history_vs_tamerlane_the_conqueror'},
#   {'title': 'Live drawings of the human experience',
#    'speaker': 'Jarrett J. Krosoczka',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/jarrett_j_krosoczka_live_drawings_of_the_human_experience'},
#   {'title': 'Why the Sun could crash your internet',
#    'speaker': 'Fabio Pacucci',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/fabio_pacucci_why_the_sun_could_crash_your_internet'},
#   {'title': 'A vision for sustainability in aviation',
#    'speaker': 'Shai Weiss',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/shai_weiss_a_vision_for_sustainability_in_aviation'},
#   {'title': "How we're turning carbon waste into jet fuel (and everything else)",
#    'speaker': 'Jennifer Holmgren',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/jennifer_holmgren_how_we_re_turning_carbon_waste_into_jet_fuel_and_everything_else'},
#   {'title': 'The 100 tampons NASA (almost) sent to space — and other absurd songs',
#    'speaker': 'Marcia Belsky',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/marcia_belsky_the_100_tampons_nasa_almost_sent_to_space_and_other_absurd_songs'},
#   {'title': '"Everything I Need" / "Find Your Tribe" / "I Am Free"',
#    'speaker': 'Geminelle',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/geminelle_everything_i_need_find_your_tribe_i_am_free'},
#   {'title': "What it's like to be a war refugee",
#    'speaker': 'Zarlasht Halaimzai',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/zarlasht_halaimzai_what_it_s_like_to_be_a_war_refugee'},
#   {'title': 'How webtoons are changing movies and TV',
#    'speaker': 'Hyeonmi Kim',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/hyeonmi_kim_how_webtoons_are_changing_movies_and_tv'},
#   {'title': 'What my gender transition taught me about womanhood',
#    'speaker': 'Paula Stone Williams',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/paula_stone_williams_what_my_gender_transition_taught_me_about_womanhood'},
#   {'title': 'A riddle of ice and fire dragons',
#    'speaker': 'Henri Picciotto',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/henri_picciotto_a_riddle_of_ice_and_fire_dragons'},
#   {'title': 'Goats, blockchain and the future of money',
#    'speaker': 'Fariel Salahuddin',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/fariel_salahuddin_goats_blockchain_and_the_future_of_money'},
#   {'title': 'What does a voice of the future sound like?',
#    'speaker': 'Reeps One',
# ...
#   {'title': '"You and I" / "Attention"',
#    'speaker': 'Charlie Puth',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/charlie_puth_you_and_i_attention'},
#   {'title': 'How to realistically decarbonize the oil and gas industry',
#    'speaker': 'Bjørn Otto Sverdrup',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/bjorn_otto_sverdrup_how_to_realistically_decarbonize_the_oil_and_gas_industry'},
#   {'title': 'I\'m tired of people telling me to "grind"',
#    'speaker': 'Pardis Parker',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/pardis_parker_i_m_tired_of_people_telling_me_to_grind'},
#   {'title': 'How biochar removes CO2 from the air — and helps farmers thrive',
#    'speaker': 'Axel Reinaud',
#    'posted_on': 'Jan 2022',
#    'talk_link': '/talks/axel_reinaud_how_biochar_removes_co2_from_the_air_and_helps_farmers_thrive'},
#   {'title': 'The most powerful untapped resource in health care',
#    'speaker': 'Edith Elliott and Shahed Alam',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/edith_elliott_and_shahed_alam_the_most_powerful_untapped_resource_in_health_care'},
#   {'title': 'A bold plan for transforming access to the US social safety net',
#    'speaker': 'Amanda Renteria',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/amanda_renteria_a_bold_plan_for_transforming_access_to_the_us_social_safety_net'},
#   {'title': 'A transparent, easy way for smallholder farmers to save',
#    'speaker': 'Anushka Ratnayake',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/anushka_ratnayake_a_transparent_easy_way_for_smallholder_farmers_to_save'},
#   {'title': 'An election redesign to restore trust in US democracy',
#    'speaker': 'Tiana Epps-Johnson',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/tiana_epps_johnson_an_election_redesign_to_restore_trust_in_us_democracy'},
#   {'title': 'Mental health care that disrupts cycles of violence',
#    'speaker': 'Celina de Sola',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/celina_de_sola_mental_health_care_that_disrupts_cycles_of_violence'},
#   {'title': 'How ancient Arctic carbon threatens everyone on the planet',
#    'speaker': 'Sue Natali',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/sue_natali_how_ancient_arctic_carbon_threatens_everyone_on_the_planet'},
#   {'title': 'Why Indigenous forest guardianship is crucial to climate action',
#    'speaker': 'Nonette Royo',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/nonette_royo_why_indigenous_forest_guardianship_is_crucial_to_climate_action'},
#   {'title': 'A safe pathway to resettlement for migrants and refugees',
#    'speaker': 'Becca Heller',
#    'posted_on': 'May 2022',
#    'talk_link': '/talks/becca_heller_a_safe_pathway_to_resettlement_for_migrants_and_refugees'},
#   {'title': 'How to heal a divided world',
#    'speaker': 'Michèle Lamont',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/michele_lamont_how_to_heal_a_divided_world'},
#   {'title': 'The restorative power of medical tattoos',
#    'speaker': 'Becky Barker',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/becky_barker_the_restorative_power_of_medical_tattoos'},
#   {'title': 'The myth of the original star-crossed lovers',
#    'speaker': 'Shannon Zhao',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/shannon_zhao_the_myth_of_the_original_star_crossed_lovers'},
#   {'title': 'The breakthrough science of mRNA medicine',
#    'speaker': 'Melissa J. Moore',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/melissa_j_moore_the_breakthrough_science_of_mrna_medicine'},
#   {'title': 'Can you solve the feeding frenzy riddle?',
#    'speaker': 'Henri Picciotto',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/henri_picciotto_can_you_solve_the_feeding_frenzy_riddle'},
#   {'title': 'The funding gap in start-up investing',
#    'speaker': 'Temie Giwa-Tubosun',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/temie_giwa_tubosun_the_funding_gap_in_start_up_investing'},
#   {'title': 'How the James Webb Space Telescope will unfold the universe',
#    'speaker': 'John C. Mather',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/john_c_mather_how_the_james_webb_space_telescope_will_unfold_the_universe'},
#   {'title': 'We can make COVID-19 the last pandemic',
#    'speaker': 'Bill Gates',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/bill_gates_we_can_make_covid_19_the_last_pandemic'},
#   {'title': 'Why people and AI make good business partners',
#    'speaker': 'Shervin Khodabandeh',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/shervin_khodabandeh_why_people_and_ai_make_good_business_partners'},
#   {'title': 'The dark history of zombies',
#    'speaker': 'Christopher M. Moreman',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/christopher_m_moreman_the_dark_history_of_zombies'},
#   {'title': 'A new economic model for protecting tropical forests',
#    'speaker': 'Nat Keohane',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/nat_keohane_a_new_economic_model_for_protecting_tropical_forests'},
#   {'title': "An Olympic champion's mindset for overcoming fear",
#    'speaker': 'Allyson Felix',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/allyson_felix_an_olympic_champion_s_mindset_for_overcoming_fear'},
#   {'title': 'Why are cockroaches so hard to kill?',
#    'speaker': 'Ameya Gondhalekar',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/ameya_gondhalekar_why_are_cockroaches_so_hard_to_kill'},
#   {'title': 'A future worth getting excited about',
#    'speaker': 'Elon Musk',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/elon_musk_a_future_worth_getting_excited_about'},
#   {'title': 'Elon Musk talks Twitter, Tesla and how his brain works — live at TED2022',
#    'speaker': 'Elon Musk',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/elon_musk_elon_musk_talks_twitter_tesla_and_how_his_brain_works_live_at_ted2022'},
#   {'title': 'The myth of Hades and Persephone',
#    'speaker': 'Iseult Gillespie',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/iseult_gillespie_the_myth_of_hades_and_persephone'},
#   {'title': "Ukraine's fight to keep educating its children",
#    'speaker': 'Zoya Lytvyn',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/zoya_lytvyn_ukraine_s_fight_to_keep_educating_its_children'},
#   {'title': 'Nuclear threat and the war in Ukraine',
#    'speaker': 'Emma Belcher',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/emma_belcher_nuclear_threat_and_the_war_in_ukraine'},
#   {'title': 'The likability dilemma for women leaders',
#    'speaker': 'Robin Hauser',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/robin_hauser_the_likability_dilemma_for_women_leaders_apr_2022'},
#   {'title': 'Ethical dilemma: Who should you believe?',
#    'speaker': 'Alex Worsnip',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/alex_worsnip_ethical_dilemma_who_should_you_believe'},
#   {'title': 'Stand with Ukraine in the fight against evil',
#    'speaker': 'Garry Kasparov',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/garry_kasparov_stand_with_ukraine_in_the_fight_against_evil'},
#   {'title': 'We could kick-start life on another planet. Should we?',
#    'speaker': 'Betül Kaçar',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/betul_kacar_we_could_kick_start_life_on_another_planet_should_we'},
#   {'title': "If you're scared of snakes, watch this",
#    'speaker': 'Andrew Whitworth',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/andrew_whitworth_if_you_re_scared_of_snakes_watch_this'},
#   {'title': 'The rhythm and rhyme of memory, solitude and community',
#    'speaker': 'Rosanne Cash',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/rosanne_cash_the_rhythm_and_rhyme_of_memory_solitude_and_community'},
#   {'title': '5 promising factors propelling climate action',
#    'speaker': 'Gabriel Kra',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/gabriel_kra_5_promising_factors_propelling_climate_action'},
#   {'title': 'NFTs, the metaverse and the future of digital art',
#    'speaker': 'Elizabeth Strickler',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/elizabeth_strickler_nfts_the_metaverse_and_the_future_of_digital_art'},
#   {'title': 'History vs. Tamerlane the Conqueror',
#    'speaker': 'Stephanie Honchell Smith',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/stephanie_honchell_smith_history_vs_tamerlane_the_conqueror'},
#   {'title': 'Live drawings of the human experience',
#    'speaker': 'Jarrett J. Krosoczka',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/jarrett_j_krosoczka_live_drawings_of_the_human_experience'},
#   {'title': 'Why the Sun could crash your internet',
#    'speaker': 'Fabio Pacucci',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/fabio_pacucci_why_the_sun_could_crash_your_internet'},
#   {'title': 'A vision for sustainability in aviation',
#    'speaker': 'Shai Weiss',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/shai_weiss_a_vision_for_sustainability_in_aviation'},
#   {'title': "How we're turning carbon waste into jet fuel (and everything else)",
#    'speaker': 'Jennifer Holmgren',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/jennifer_holmgren_how_we_re_turning_carbon_waste_into_jet_fuel_and_everything_else'},
#   {'title': 'The 100 tampons NASA (almost) sent to space — and other absurd songs',
#    'speaker': 'Marcia Belsky',
#    'posted_on': 'Apr 2022',
#    'talk_link': '/talks/marcia_belsky_the_100_tampons_nasa_almost_sent_to_space_and_other_absurd_songs'},
#   {'title': '"Everything I Need" / "Find Your Tribe" / "I Am Free"',
#    'speaker': 'Geminelle',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/geminelle_everything_i_need_find_your_tribe_i_am_free'},
#   {'title': "What it's like to be a war refugee",
#    'speaker': 'Zarlasht Halaimzai',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/zarlasht_halaimzai_what_it_s_like_to_be_a_war_refugee'},
#   {'title': 'How webtoons are changing movies and TV',
#    'speaker': 'Hyeonmi Kim',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/hyeonmi_kim_how_webtoons_are_changing_movies_and_tv'},
#   {'title': 'What my gender transition taught me about womanhood',
#    'speaker': 'Paula Stone Williams',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/paula_stone_williams_what_my_gender_transition_taught_me_about_womanhood'},
#   {'title': 'A riddle of ice and fire dragons',
#    'speaker': 'Henri Picciotto',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/henri_picciotto_a_riddle_of_ice_and_fire_dragons'},
#   {'title': 'Goats, blockchain and the future of money',
#    'speaker': 'Fariel Salahuddin',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/fariel_salahuddin_goats_blockchain_and_the_future_of_money'},
#   {'title': 'What does a voice of the future sound like?',
#    'speaker': 'Reeps One',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/reeps_one_what_does_a_voice_of_the_future_sound_like'},
#   {'title': 'Why all melodies should be free for musicians to use',
#    'speaker': 'Damien Riehl',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/damien_riehl_why_all_melodies_should_be_free_for_musicians_to_use'},
#   {'title': 'The Chinese legend of the butterfly lovers',
#    'speaker': 'Lijun Zhang',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/lijun_zhang_the_chinese_legend_of_the_butterfly_lovers'},
#   {'title': "The African swamp protecting Earth's environment",
#    'speaker': 'Vera Songwe',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/vera_songwe_the_african_swamp_protecting_earth_s_environment'},
#   {'title': 'The future will be shaped by optimists',
#    'speaker': 'Kevin Kelly',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/kevin_kelly_the_future_will_be_shaped_by_optimists'},
#   {'title': "How do you know you're not dreaming?",
#    'speaker': 'Daniel Gregory',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/daniel_gregory_how_do_you_know_you_re_not_dreaming'},
#   {'title': 'The hidden power of sad songs and rainy days',
#    'speaker': 'Susan Cain and Min Kym',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/susan_cain_and_min_kym_the_hidden_power_of_sad_songs_and_rainy_days'},
#   {'title': 'Powerful photos that honor the lives of overlooked women',
#    'speaker': 'Smita Sharma',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/smita_sharma_powerful_photos_that_honor_the_lives_of_overlooked_women'},
#   {'title': 'Why entrepreneurship flourishes in the countryside',
#    'speaker': 'Xiaowei R. Wang',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/xiaowei_r_wang_why_entrepreneurship_flourishes_in_the_countryside'},
#   {'title': "The deep sea's medicinal secrets",
#    'speaker': 'Sam Afoullouss',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/sam_afoullouss_the_deep_sea_s_medicinal_secrets'},
#   {'title': '4 signs of emotional abuse',
#    'speaker': 'Viann Nguyen-Feng',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/viann_nguyen_feng_4_signs_of_emotional_abuse'},
#   {'title': 'The power of purpose in business',
#    'speaker': 'Ashley M. Grice',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/ashley_m_grice_the_power_of_purpose_in_business'},
#   {'title': "Climate change isn't a distant threat — it's our reality",
#    'speaker': 'Selina Neirok Leem',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/selina_neirok_leem_climate_change_isn_t_a_distant_threat_it_s_our_reality'},
#   {'title': 'How pigeons took over the world',
#    'speaker': 'Elizabeth Carlen and Joanna Moles',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/elizabeth_carlen_and_joanna_moles_how_pigeons_took_over_the_world'},
#   {'title': '3 things men can do to promote gender equity',
#    'speaker': 'Jimmie Briggs',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/jimmie_briggs_3_things_men_can_do_to_promote_gender_equity'},
#   {'title': 'Self-assembling robots and the potential of artificial evolution',
#    'speaker': 'Emma Hart',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/emma_hart_self_assembling_robots_and_the_potential_of_artificial_evolution'},
#   {'title': 'What does it mean to be a refugee?',
#    'speaker': 'Benedetta Berti and Evelien Borgman',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/benedetta_berti_and_evelien_borgman_what_does_it_mean_to_be_a_refugee_mar_2018'},
#   {'title': 'War in Ukraine — and what it means for the world order',
#    'speaker': 'Ian Bremmer',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/ian_bremmer_war_in_ukraine_and_what_it_means_for_the_world_order'},
#   {'title': 'How to design mosquitoes out of cities',
#    'speaker': 'Cameron Webb',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/cameron_webb_how_to_design_mosquitoes_out_of_cities'},
#   {'title': 'An aerial perspective on renewable energy',
#    'speaker': 'Jamey Stillings',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/jamey_stillings_an_aerial_perspective_on_renewable_energy'},
#   {'title': 'The movement that inspired the Holocaust',
#    'speaker': 'Alexandra Minna Stern and Natalie Lira',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/alexandra_minna_stern_and_natalie_lira_the_movement_that_inspired_the_holocaust'},
#   {'title': 'The critical role of Black mothers — and how to support all moms',
#    'speaker': 'Anna Malaika Tubbs',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/anna_malaika_tubbs_the_critical_role_of_black_mothers_and_how_to_support_all_moms'},
#   {'title': 'The creativity and community behind fanfiction',
#    'speaker': 'Cecilia Aragon',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/cecilia_aragon_the_creativity_and_community_behind_fanfiction'},
#   {'title': '3 ways to find hope in hopeless times',
#    'speaker': 'Wajahat Ali',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/wajahat_ali_3_ways_to_find_hope_in_hopeless_times'},
#   {'title': 'The myth of the moon goddess',
#    'speaker': 'Cynthia Fay Davis',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/cynthia_fay_davis_the_myth_of_the_moon_goddess'},
#   {'title': 'How to share public money fairly',
#    'speaker': 'Maja Bosnic',
#    'posted_on': 'Mar 2022',
#    'talk_link': '/talks/maja_bosnic_how_to_share_public_money_fairly'}]]

# %%
with open('ted_talks.json', 'w') as file:
    json.dump(all_talks, file, indent=4)

# %%
with open('ted_talks.json', 'r') as file:
    talks = json.load(file)
talks[:3]
# Out:
# [{'title': '"I Hope" / "DAWN"',
#   'speaker': 'Resistance Revival Chorus',
#   'posted_on': 'Mar 2022',
#   'talk_link': '/talks/resistance_revival_chorus_i_hope_dawn'},
#  {'title': '"A seat at the table" isn\'t the solution for gender equity',
#   'speaker': 'Lilly Singh',
#   'posted_on': 'Mar 2022',
#   'talk_link': '/talks/lilly_singh_a_seat_at_the_table_isn_t_the_solution_for_gender_equity'},
#  {'title': 'Why US laws must expand beyond the nuclear family',
#   'speaker': 'Diana Adams',
#   'posted_on': 'Mar 2022',
#   'talk_link': '/talks/diana_adams_why_us_laws_must_expand_beyond_the_nuclear_family'}]

# %%
len(talks)
# Out:
# 252
